# %% [markdown]
# # fbprophet 모델을 활용한 인공지능 비트 트레이더 경진대회 베이스라인 코드

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !pip install statsmodels==0.11.1
# !pip install fbprophet

# %% [markdown]
# # 1. Library Import

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /home/aiffel-dj19/anaconda3/envs/moduway/lib/python3.9/site-packages (4.14.3)
# Requirement already satisfied: six in /home/aiffel-dj19/anaconda3/envs/moduway/lib/python3.9/site-packages (from plotly) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /home/aiffel-dj19/anaconda3/envs/moduway/lib/python3.9/site-packages (from plotly) (1.3.3)

# %%
import numpy as np
import pandas as pd
import gc
import math
import os.path
import time
import matplotlib.pyplot as plt
from datetime import timedelta, datetime
from dateutil import parser
from tqdm import tqdm
import copy
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from fbprophet import Prophet
import warnings
import datetime
from plotly import tools 
import plotly.offline as offline 
import plotly.graph_objs as go 
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. 데이터 불러오기

# %% [markdown]
# ## 1) read_csv

# %%
data_path = os.getenv('HOME') + '/dacon/ModuWay/baseline/data' # 경로 다름! 변경해줘야함
# data_path = os.getenv('HOME') + '/ModuWay/data'
train_x_df = pd.read_csv(data_path  + "/train_x_df.csv")
train_y_df = pd.read_csv(data_path  + "/train_y_df.csv")
test_x_df = pd.read_csv(data_path  + "/test_x_df.csv")

# %% [markdown]
# * sample_id : 개별 샘플의 인덱스
# * time : x_df는 0분 ~ 1379분, y_df는 0분 ~ 119분의 값을 갖습니다. 동일한 샘플 내 시간 정보
# * coin_index : 10가지 종류의 코인에 대한 비식별화 인덱스 (0 ~9)
# * open : open price
# * high : high price
# * low : low price
# * close : close price
# * volume : 거래량
# * quote_av : quote asset volume
# * trades : 거래 건 수
# * tb_base_av : taker buy base asset volume
# * tb_quote_av : taker buy quote asset volume

# %%
train_x_df
# Out:
#           sample_id  time  coin_index      open      high       low     close  \
# 0                 0     0           7  1.010004  1.010004  1.009612  1.010004
# 1                 0     1           7  1.009808  1.009808  1.009808  1.009808
# 2                 0     2           7  1.009808  1.010200  1.009808  1.010200
# 3                 0     3           7  1.010200  1.011181  1.010200  1.011181
# 4                 0     4           7  1.010985  1.010985  1.010200  1.010200
# ...             ...   ...         ...       ...       ...       ...       ...
# 10159555       7361  1375           8  1.000668  1.001669  1.000626  1.001502
# 10159556       7361  1376           8  1.001627  1.001920  1.000960  1.001294
# 10159557       7361  1377           8  1.001294  1.001461  1.000584  1.000668
# 10159558       7361  1378           8  1.000709  1.000751  1.000042  1.000042
# 10159559       7361  1379           8  1.000000  1.000918  0.999958  1.000876
#
#                 volume       quote_av      trades    tb_base_av    tb_quote_av
# 0         8.382875e+05   43160.632812  451.157288  7.326834e+05   37725.183594
# 1         1.622420e+05    8352.220703   39.231071  0.000000e+00       0.000000
# 2         1.664967e+04     857.377808   58.846603  1.664967e+04     857.377808
# 3         2.586971e+06  133310.343750  431.541779  2.189147e+06  112811.046875
# 4         1.129996e+06   58216.867188  176.539810  0.000000e+00       0.000000
# ...                ...            ...         ...           ...            ...
# 10159555  9.180907e+00    2203.059082    2.245034  6.229020e+00    1494.727417
# 10159556  7.963097e+00    1911.151611    2.211651  3.056139e+00     733.490601
# 10159557  3.849893e+00     923.610718    1.260224  2.284546e+00     548.042297
# 10159558  1.337402e+00     320.624756    0.826239  5.164965e-01     123.819839
# 10159559  1.278548e+00     306.542389    0.642631  7.320906e-01     175.527679
#
# [10159560 rows x 12 columns]

# %%
# create 7 mins simple moving average column
train_x_df['7_SMA'] = train_x_df['close'].rolling(window = 7, min_periods=1).mean()
# create 25 mins simple moving average column
train_x_df['25_SMA'] = train_x_df['close'].rolling(window = 25,  min_periods=1).mean()
# display few rows
train_x_df
# Out:
#           sample_id  time  coin_index      open      high       low     close  \
# 0                 0     0           7  1.010004  1.010004  1.009612  1.010004
# 1                 0     1           7  1.009808  1.009808  1.009808  1.009808
# 2                 0     2           7  1.009808  1.010200  1.009808  1.010200
# 3                 0     3           7  1.010200  1.011181  1.010200  1.011181
# 4                 0     4           7  1.010985  1.010985  1.010200  1.010200
# ...             ...   ...         ...       ...       ...       ...       ...
# 10159555       7361  1375           8  1.000668  1.001669  1.000626  1.001502
# 10159556       7361  1376           8  1.001627  1.001920  1.000960  1.001294
# 10159557       7361  1377           8  1.001294  1.001461  1.000584  1.000668
# 10159558       7361  1378           8  1.000709  1.000751  1.000042  1.000042
# 10159559       7361  1379           8  1.000000  1.000918  0.999958  1.000876
#
#                 volume       quote_av      trades    tb_base_av  \
# 0         8.382875e+05   43160.632812  451.157288  7.326834e+05
# 1         1.622420e+05    8352.220703   39.231071  0.000000e+00
# 2         1.664967e+04     857.377808   58.846603  1.664967e+04
# 3         2.586971e+06  133310.343750  431.541779  2.189147e+06
# 4         1.129996e+06   58216.867188  176.539810  0.000000e+00
# ...                ...            ...         ...           ...
# 10159555  9.180907e+00    2203.059082    2.245034  6.229020e+00
# 10159556  7.963097e+00    1911.151611    2.211651  3.056139e+00
# 10159557  3.849893e+00     923.610718    1.260224  2.284546e+00
# 10159558  1.337402e+00     320.624756    0.826239  5.164965e-01
# 10159559  1.278548e+00     306.542389    0.642631  7.320906e-01
#
#             tb_quote_av     7_SMA    25_SMA
# 0          37725.183594  1.010004  1.010004
# 1              0.000000  1.009906  1.009906
# 2            857.377808  1.010004  1.010004
# 3         112811.046875  1.010298  1.010298
# 4              0.000000  1.010279  1.010279
# ...                 ...       ...       ...
# 10159555    1494.727417  0.999350  0.998212
# 10159556     733.490601  0.999815  0.998289
# 10159557     548.042297  1.000101  0.998314
# 10159558     123.819839  1.000364  0.998307
# 10159559     175.527679  1.000656  0.998346
#
# [10159560 rows x 14 columns]

# %% [markdown]
# 이삭님 구현하고 싶은 거: sample_id별로 macd 즉, 평균을 구했어야함. 근데 지금 코드에서는 단순히 전체 종가의 평균을 구했음 => 코드 수정 필요

# %%
len(train_x_df['sample_id'].unique().tolist())
# Out:
# 7362

# %%
sample_id_lst = train_x_df['sample_id'].unique().tolist()

# %%
train_x_df['sample_id'].value_counts()
# Out:
# 0       1380
# 4919    1380
# 4913    1380
# 4912    1380
# 4915    1380
#         ...
# 2451    1380
# 2448    1380
# 2449    1380
# 2446    1380
# 7360    1380
# Name: sample_id, Length: 7362, dtype: int64

# %%
train_x_df[train_x_df['sample_id']==0]['close'].mean()
# Out:
# 1.000142535869626

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /home/aiffel-dj19/anaconda3/envs/moduway/lib/python3.9/site-packages (4.59.0)

# %%
df = train_x_df

# %%
df.head()
# Out:
#    sample_id  time  coin_index      open      high       low     close  \
# 0          0     0           7  1.010004  1.010004  1.009612  1.010004
# 1          0     1           7  1.009808  1.009808  1.009808  1.009808
# 2          0     2           7  1.009808  1.010200  1.009808  1.010200
# 3          0     3           7  1.010200  1.011181  1.010200  1.011181
# 4          0     4           7  1.010985  1.010985  1.010200  1.010200
#
#          volume       quote_av      trades    tb_base_av    tb_quote_av  \
# 0  8.382875e+05   43160.632812  451.157288  7.326834e+05   37725.183594
# 1  1.622420e+05    8352.220703   39.231071  0.000000e+00       0.000000
# 2  1.664967e+04     857.377808   58.846603  1.664967e+04     857.377808
# 3  2.586971e+06  133310.343750  431.541779  2.189147e+06  112811.046875
# 4  1.129996e+06   58216.867188  176.539810  0.000000e+00       0.000000
#
#       7_SMA    25_SMA  macd
# 0  1.010004  1.010004     0
# 1  1.009906  1.009906     0
# 2  1.010004  1.010004     0
# 3  1.010298  1.010298     0
# 4  1.010279  1.010279     0

# %%
df['macd'] = 0 
df.head()
# Out:
#    sample_id  time  coin_index      open      high       low     close  \
# 0          0     0           7  1.010004  1.010004  1.009612  1.010004
# 1          0     1           7  1.009808  1.009808  1.009808  1.009808
# 2          0     2           7  1.009808  1.010200  1.009808  1.010200
# 3          0     3           7  1.010200  1.011181  1.010200  1.011181
# 4          0     4           7  1.010985  1.010985  1.010200  1.010200
#
#          volume       quote_av      trades    tb_base_av    tb_quote_av  \
# 0  8.382875e+05   43160.632812  451.157288  7.326834e+05   37725.183594
# 1  1.622420e+05    8352.220703   39.231071  0.000000e+00       0.000000
# 2  1.664967e+04     857.377808   58.846603  1.664967e+04     857.377808
# 3  2.586971e+06  133310.343750  431.541779  2.189147e+06  112811.046875
# 4  1.129996e+06   58216.867188  176.539810  0.000000e+00       0.000000
#
#       7_SMA    25_SMA  macd
# 0  1.010004  1.010004     0
# 1  1.009906  1.009906     0
# 2  1.010004  1.010004     0
# 3  1.010298  1.010298     0
# 4  1.010279  1.010279     0

# %%
close_df = df[['sample_id', 'close']]

# %%
tmp_df = df[df['sample_id'] == 0]['close']
tmp_df.head()
# Out:
# 0    1.010004
# 1    1.009808
# 2    1.010200
# 3    1.011181
# 4    1.010200
# Name: close, dtype: float64

# %%
ma_12 = tmp_df['close'].ewm(span=12).mean()
ma_26 = tmp_df['close'].ewm(span=26).mean()

# %%
df['macd'] = 0
df['macd'] = ma_12 - ma_26
df.head()
# Out:
#    sample_id  time  coin_index      open      high       low     close  \
# 0          0     0           7  1.010004  1.010004  1.009612  1.010004
# 1          0     1           7  1.009808  1.009808  1.009808  1.009808
# 2          0     2           7  1.009808  1.010200  1.009808  1.010200
# 3          0     3           7  1.010200  1.011181  1.010200  1.011181
# 4          0     4           7  1.010985  1.010985  1.010200  1.010200
#
#          volume       quote_av      trades    tb_base_av    tb_quote_av  \
# 0  8.382875e+05   43160.632812  451.157288  7.326834e+05   37725.183594
# 1  1.622420e+05    8352.220703   39.231071  0.000000e+00       0.000000
# 2  1.664967e+04     857.377808   58.846603  1.664967e+04     857.377808
# 3  2.586971e+06  133310.343750  431.541779  2.189147e+06  112811.046875
# 4  1.129996e+06   58216.867188  176.539810  0.000000e+00       0.000000
#
#       7_SMA    25_SMA      macd  ma_12
# 0  1.010004  1.010004  0.000000      0
# 1  1.009906  1.009906 -0.000004      0
# 2  1.010004  1.010004  0.000007      0
# 3  1.010298  1.010298  0.000047      0
# 4  1.010279  1.010279  0.000029      0

# %%
df['macd'].map(lambda x: 2) # lambda 기능 확인 
df
# Out:
#           sample_id  time  coin_index      open      high       low     close  \
# 0                 0     0           7  1.010004  1.010004  1.009612  1.010004
# 1                 0     1           7  1.009808  1.009808  1.009808  1.009808
# 2                 0     2           7  1.009808  1.010200  1.009808  1.010200
# 3                 0     3           7  1.010200  1.011181  1.010200  1.011181
# 4                 0     4           7  1.010985  1.010985  1.010200  1.010200
# ...             ...   ...         ...       ...       ...       ...       ...
# 10159555       7361  1375           8  1.000668  1.001669  1.000626  1.001502
# 10159556       7361  1376           8  1.001627  1.001920  1.000960  1.001294
# 10159557       7361  1377           8  1.001294  1.001461  1.000584  1.000668
# 10159558       7361  1378           8  1.000709  1.000751  1.000042  1.000042
# 10159559       7361  1379           8  1.000000  1.000918  0.999958  1.000876
#
#                 volume       quote_av      trades    tb_base_av  \
# 0         8.382875e+05   43160.632812  451.157288  7.326834e+05
# 1         1.622420e+05    8352.220703   39.231071  0.000000e+00
# 2         1.664967e+04     857.377808   58.846603  1.664967e+04
# 3         2.586971e+06  133310.343750  431.541779  2.189147e+06
# 4         1.129996e+06   58216.867188  176.539810  0.000000e+00
# ...                ...            ...         ...           ...
# 10159555  9.180907e+00    2203.059082    2.245034  6.229020e+00
# 10159556  7.963097e+00    1911.151611    2.211651  3.056139e+00
# 10159557  3.849893e+00     923.610718    1.260224  2.284546e+00
# 10159558  1.337402e+00     320.624756    0.826239  5.164965e-01
# 10159559  1.278548e+00     306.542389    0.642631  7.320906e-01
#
#             tb_quote_av     7_SMA    25_SMA  macd  ma_12
# 0          37725.183594  1.010004  1.010004     1      0
# 1              0.000000  1.009906  1.009906     1      0
# 2            857.377808  1.010004  1.010004     1      0
# 3         112811.046875  1.010298  1.010298     1      0
# 4              0.000000  1.010279  1.010279     1      0
# ...                 ...       ...       ...   ...    ...
# 10159555    1494.727417  0.999350  0.998212     1      0
# 10159556     733.490601  0.999815  0.998289     1      0
# 10159557     548.042297  1.000101  0.998314     1      0
# 10159558     123.819839  1.000364  0.998307     1      0
# 10159559     175.527679  1.000656  0.998346     1      0
#
# [10159560 rows x 16 columns]

# %%
df['ma_12'] = 0 
for sample_id_i in tqdm(sample_id_lst): # tqdm으로 진행바 표시 
    df['ma_12'] = df['ma_12'].apply(lambda x: train_x_df[train_x_df['sample_id']==sample_id_i]['close'].ewm(span=12).mean()) # lambda 기능 확인
# Out:
#   0%|          | 0/7362 [08:29<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-0a2c7f4919b2> in <module>
#       1 df['ma_12'] = 0
#       2 for sample_id_i in tqdm(sample_id_lst): # tqdm으로 진행바 표시
# ----> 3     df['ma_12'] = df['ma_12'].apply(lambda x: train_x_df[train_x_df['sample_id']==sample_id_i]['close'].ewm(span=12).mean()) # lambda 기능 확인
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-36-0a2c7f4919b2> in <lambda>(x)
#       1 df['ma_12'] = 0
#       2 for sample_id_i in tqdm(sample_id_lst): # tqdm으로 진행바 표시
# ----> 3     df['ma_12'] = df['ma_12'].apply(lambda x: train_x_df[train_x_df['sample_id']==sample_id_i]['close'].ewm(span=12).mean()) # lambda 기능 확인
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
#      30
#      31     @unpack_zerodim_and_defer("__ne__")
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    4976         rvalues = extract_array(other, extract_numpy=True)
#    4977
# -> 4978         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4979
#    4980         return self._construct_result(res_values, name=res_name)
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     248             warnings.simplefilter("ignore", DeprecationWarning)
#     249             with np.errstate(all="ignore"):
# --> 250                 res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#     251
#     252     return res_values
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     140
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#     144         if is_cmp:
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     233         if use_numexpr:
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#     237
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      67         _store_test_result(False)
#      68     with np.errstate(all="ignore"):
# ---> 69         return op(a, b)
#      70
#      71
#
# KeyboardInterrupt:

# %%
close_df['ma_12'] = 0
close_df['ma_26'] = 0
close_df['macd'] = 0
close_df['macds'] = 0
close_df['macdo'] = 0
close_df
# Out:
#           sample_id     close  macd  macds  macdo  ma_12  ma_26
# 0                 0  1.010004     0      0      0      0      0
# 1                 0  1.009808     0      0      0      0      0
# 2                 0  1.010200     0      0      0      0      0
# 3                 0  1.011181     0      0      0      0      0
# 4                 0  1.010200     0      0      0      0      0
# ...             ...       ...   ...    ...    ...    ...    ...
# 10159555       7361  1.001502     0      0      0      0      0
# 10159556       7361  1.001294     0      0      0      0      0
# 10159557       7361  1.000668     0      0      0      0      0
# 10159558       7361  1.000042     0      0      0      0      0
# 10159559       7361  1.000876     0      0      0      0      0
#
# [10159560 rows x 7 columns]

# %%
group_close_df = close_df.groupby('sample_id')
group_close_df.head()
# Out:
#           sample_id     close      macd     macds     macdo  ma_12  ma_26
# 0                 0  1.010004  0.000000  0.000000  0.000000    NaN    NaN
# 1                 0  1.009808 -0.000004 -0.000002 -0.000002    NaN    NaN
# 2                 0  1.010200  0.000007  0.000001  0.000005    NaN    NaN
# 3                 0  1.011181  0.000047  0.000017  0.000030    NaN    NaN
# 4                 0  1.010200  0.000029  0.000020  0.000008    NaN    NaN
# ...             ...       ...       ...       ...       ...    ...    ...
# 10158180       7361  0.998456       NaN       NaN       NaN    NaN    NaN
# 10158181       7361  0.998623       NaN       NaN       NaN    NaN    NaN
# 10158182       7361  0.997872       NaN       NaN       NaN    NaN    NaN
# 10158183       7361  0.998414       NaN       NaN       NaN    NaN    NaN
# 10158184       7361  0.999291       NaN       NaN       NaN    NaN    NaN
#
# [36810 rows x 7 columns]

# %%
for sample_id_i in tqdm(sample_id_lst): # tqdm으로 진행바 표시 
    # MACD 관련 수식 
    close_df.ma_12 = close_df[close_df['sample_id']==sample_id_i]['close'].ewm(span=12).mean() # 단기(12) EMA(지수이동평균)
# Out:
#  81%|████████▏ | 5994/7362 [22:21<04:28,  5.09it/s]

# %%
# 나중에 함수로 정리(train_x_df, train_y_df, test_x_df, test_y_df)
from tqdm import tqdm 
import time

if os.path.isfile(data_path + '/train_x_macd_df.csv'):
    print(f'train_x_df의 macd 계산을 완료했습니다.')
    pass 

else:
    for sample_id_i in tqdm(sample_id_lst): # tqdm으로 진행바 표시 
        # MACD 관련 수식 
        close_df.ma_12 = close_df[close_df['sample_id']==sample_id_i]['close'].ewm(span=12).mean() # 단기(12) EMA(지수이동평균) 
        close_df.ma_26 = close_df[close_df['sample_id']==sample_id_i]['close'].ewm(span=26).mean() # 장기(26) EMA 
        close_df.macd = ma_12 - ma_26 # MACD 
        close_df.macds = macd.ewm(span=9).mean() # Signal 
        close_df.macdo = macd - macds # Oscillator 
        
close_df.to_csv(data_path + '/train_x_macd_df.csv')
# Out:
#   1%|          | 88/7362 [02:18<3:11:04,  1.58s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-28f1c1dc4976> in <module>
#      10     for sample_id_i in tqdm(sample_id_lst): # tqdm으로 진행바 표시
#      11         # MACD 관련 수식
# ---> 12         close_df.ma_12 = close_df[close_df['sample_id']==sample_id_i]['close'].ewm(span=12).mean() # 단기(12) EMA(지수이동평균)
#      13         close_df.ma_26 = close_df[close_df['sample_id']==sample_id_i]['close'].ewm(span=26).mean() # 장기(26) EMA
#      14         close_df.macd = ma_12 - ma_26 # MACD
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5492                     object.__setattr__(self, name, value)
#    5493                 elif name in self._info_axis:
# -> 5494                     self[name] = value
#    5495                 else:
#    5496                     object.__setattr__(self, name, value)
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3874
#    3875         if isinstance(value, Series):
# -> 3876             value = reindexer(value)
#    3877
#    3878         elif isinstance(value, DataFrame):
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/frame.py in reindexer(value)
#    3860                 # GH 4107
#    3861                 try:
# -> 3862                     value = value.reindex(self.index)._values
#    3863                 except ValueError as err:
#    3864                     # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4343     )
#    4344     def reindex(self, index=None, **kwargs):
# -> 4345         return super().reindex(index=index, **kwargs)
#    4346
#    4347     def drop(
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4809
#    4810         # perform the reindex on the axes
# -> 4811         return self._reindex_axes(
#    4812             axes, level, limit, tolerance, method, fill_value, copy
#    4813         ).__finalize__(self, method="reindex")
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4825
#    4826             ax = self._get_axis(a)
# -> 4827             new_index, indexer = ax.reindex(
#    4828                 labels, level=level, limit=limit, tolerance=tolerance, method=method
#    4829             )
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    3514             else:
#    3515                 if self._index_as_unique:
# -> 3516                     indexer = self.get_indexer(
#    3517                         target, method=method, limit=limit, tolerance=tolerance
#    3518                     )
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3189                 )
#    3190
# -> 3191             indexer = self._engine.get_indexer(target._get_engine_target())
#    3192
#    3193         return ensure_platform_int(indexer)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.lookup()
#
# ~/anaconda3/envs/moduway/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      12 ]
#      13
# ---> 14 @set_module('numpy')
#      15 def asarray(a, dtype=None, order=None):
#      16     """Convert the input to an array.
#
# KeyboardInterrupt:

# %%
# create 7 mins simple moving average column
train_y_df['7_SMA'] = train_y_df['close'].rolling(window = 7, min_periods=1).mean()
# create 25 mins simple moving average column
train_y_df['25_SMA'] = train_y_df['close'].rolling(window = 25,  min_periods=1).mean()

train_y_df = get_macd(train_y_df) 

# 데이터 확인 
train_y_df

# %%
test_x_df

# %%
# create 7 mins simple moving average column
test_x_df['7_SMA'] = test_x_df['close'].rolling(window = 7, min_periods=1).mean()
# create 25 mins simple moving average column
test_x_df['25_SMA'] = test_x_df['close'].rolling(window = 25,  min_periods=1).mean()

test_x_df = get_macd(test_x_df) 

# 데이터 확인 
test_x_df

# %% [markdown]
# ## 2) numpy arrary로 변환하기

# %%
def df2d_to_array3d(df_2d):
    # 입력 받은 2차원 데이터 프레임을 3차원 numpy array로 변경하는 함수
    feature_size = df_2d.iloc[:,2:].shape[1]
    time_size = len(df_2d.time.value_counts())
    sample_size = len(df_2d.sample_id.value_counts())
    sample_index = df_2d.sample_id.value_counts().index
    array_3d = df_2d.iloc[:,2:].values.reshape([sample_size, time_size, feature_size])
    return array_3d

# %%
train_x_array = df2d_to_array3d(train_x_df)
train_y_array = df2d_to_array3d(train_y_df)
test_x_array = df2d_to_array3d(test_x_df)

# %%
print(f'''
train_x_array {train_x_array.shape}
train_y_array {train_y_array.shape}
test_x_array {test_x_array.shape}
''')

# %% [markdown]
# ## MACD 시각화

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.ticker as ticker
import numpy as np

# %%
idx = 1000
index = train_x_df[train_x_df['sample_id']==idx].time.tolist()
type(index), len(index)

# %%
# loc 쓰기 귀찮아서 데이터 프레임으로.. 그냥 .. 때려..넣기? => 나중에 수정
sample_x_df = pd.DataFrame()
sample_x_df = train_x_df[['sample_id','7_SMA', '25_SMA','macd','macdo','macds']]
sample_x_df.head()

# %%
sma7_lst = sample_x_df['7_SMA'].loc[sample_x_df['sample_id']==idx].tolist()
sma25_lst = sample_x_df['25_SMA'].loc[sample_x_df['sample_id']==idx].tolist()

# %%
print(len(sma25_lst) == len(sma7_lst)) # 차원 일치 여부 확인 
print(type(index) == type(sma7_lst)) # 형 일치 여부 확인

# %%
index[0:2], sma7_lst[0:2] # 값 확인

# %%
# Main chart - SMA_7 and SMA_25
fig, ax = plt.subplots(figsize=(12,5))

ax.set_title('SMA_7 v.s. SMA_25', fontsize=20)

ax.plot(index, sma7_lst, 'b', lw=1, label='SMA_7')
ax.plot(index, sma25_lst, 'r', lw=1, label='SMA_25')
ax.legend(loc='best')

fig.tight_layout()

# %%
macd_lst = sample_x_df['macd'].loc[sample_x_df['sample_id']==idx].tolist()
macds_lst = sample_x_df['macds'].loc[sample_x_df['sample_id']==idx].tolist()

# %%
# index chart - MACD and MACDs
fig, ax = plt.subplots(figsize=(12,5))

ax.set_title('MACD v.s. MACD Sinal', fontsize=20)

ax.plot(index, macd_lst, 'b', lw=1, label='macd')
ax.plot(index, macds_lst, 'r', lw=1, label='macds')
ax.legend(loc='best')

fig.tight_layout()

# %%
macdo_lst = sample_x_df['macdo'].loc[sample_x_df['sample_id']==idx].tolist()

# %%
# index chart - MACDo
fig, ax = plt.subplots(figsize=(12,5))

ax.set_title('MACD Oscilator', fontsize=20)

ax.bar(index, [0 if i > 0 else i for i in macdo_lst], lw=1, label='macdo(+)')
ax.bar(index, [0 if i < 0 else i for i in macdo_lst], lw=1, label='macdo(-)')
ax.legend(loc='best')

fig.tight_layout()

# %% [markdown]
# ## MACD
